# %% [markdown]
# # explorer.ipynb has moved
#
# The interactive content from this notebook has been merged into the main predictions notebook so a reader can move sliders and break predictions in the same place those predictions are stated.
#
# **Go to [predictions.ipynb](predictions.ipynb).**
#
# Specifically:
#
# - **k_EWSB slider** → predictions.ipynb, Higgs panel
# - **N (boundary capacity) slider** → predictions.ipynb, Foundation section
# - **α t-slider** → predictions.ipynb, Fine-Structure Constant panel
# - **g (cascade scaling) slider** → predictions.ipynb, Mass Hierarchy panel
# - **Active Inference loop demo** → predictions.ipynb, Active Inference section
# - **Falsification tests** → predictions.ipynb, How to Break section
#
# For full math derivations: **[derivations.ipynb](derivations.ipynb)**.
